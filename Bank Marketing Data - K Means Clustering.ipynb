# %% [markdown]
# LINK: https://archive.ics.uci.edu/ml/datasets/bank+marketing

# %% [raw]
# nput variables:
# # bank client data:
# 1 - age (numeric)
# 2 - job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# 3 - marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# 4 - education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# 5 - default: has credit in default? (categorical: 'no','yes','unknown')
# 6 - housing: has housing loan? (categorical: 'no','yes','unknown')
# 7 - loan: has personal loan? (categorical: 'no','yes','unknown')
# # related with the last contact of the current campaign:
# 8 - contact: contact communication type (categorical: 'cellular','telephone')
# 9 - month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# 10 - day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# 11 - duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
# # other attributes:
# 12 - campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# 13 - pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# 14 - previous: number of contacts performed before this campaign and for this client (numeric)
# 15 - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
# # social and economic context attributes
# 16 - emp.var.rate: employment variation rate - quarterly indicator (numeric)
# 17 - cons.price.idx: consumer price index - monthly indicator (numeric)
# 18 - cons.conf.idx: consumer confidence index - monthly indicator (numeric)
# 19 - euribor3m: euribor 3 month rate - daily indicator (numeric)
# 20 - nr.employed: number of employees - quarterly indicator (numeric)
#
# Output variable (desired target):
# 21 - y - has the client subscribed a term deposit? (binary: 'yes','no')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../DATA/bank-full.csv")

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.histplot(data=df, x='age')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.histplot(data=df, x='age', hue='loan')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.histplot(data=df, x='pdays')
# Out:
# <AxesSubplot:xlabel='pdays', ylabel='Count'>

# %% [markdown]
# pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.histplot(data=df[df['pdays'] != 999], x='pdays')
# plt.xlim(0, 100)
# Out:
# <AxesSubplot:xlabel='pdays', ylabel='Count'>

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.histplot(data=df, x='duration', hue='contact')
plt.xlim(0, 2000)
# Out:
# (0.0, 2000.0)

# %% [markdown]
# 15 - previous: number of contacts performed before this campaign and for this client (numeric)

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.countplot(data=df, x='previous', hue='contact')
# Out:
# <AxesSubplot:xlabel='previous', ylabel='count'>

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.countplot(data=df, x='job', order=df['job'].value_counts().index)
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.countplot(data=df, x='education', order=df['education'].value_counts().index)
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(12,6), dpi=200)
sns.countplot(data=df, x='education', order=df['education'].value_counts().index, hue='default')
plt.xticks(rotation=90);

# %%
sns.countplot(data=df, x='default')
# Out:
# <AxesSubplot:xlabel='default', ylabel='count'>

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
X = pd.get_dummies(df)

# %%
X
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41183   73       334         1    999         0          -1.1          94.767
# 41184   46       383         1    999         0          -1.1          94.767
# 41185   56       189         2    999         0          -1.1          94.767
# 41186   44       442         1    999         0          -1.1          94.767
# 41187   74       239         3    999         1          -1.1          94.767
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_X = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans

# %%
ssd =[]

for k in range(1,31):
    model = KMeans(n_clusters=k)
    model.fit_predict(scaled_X)
    ssd.append(model.inertia_)

# %%
ssd
# Out:
# [2677220.0000000065,
#  2469792.3616627743,
#  2370416.3049993734,
#  2282648.2391206985,
#  2200695.0083999303,
#  2156337.4052557047,
#  2087195.0821083856,
#  2048264.2753236673,
#  2005511.6752056973,
#  1998267.0338397685,
#  1976155.1264120515,
#  1911558.1105787863,
#  1887815.7123573162,
#  1856752.7755787468,
#  1808127.7410557366,
#  1775944.818333291,
#  1773892.3817578482,
#  1728707.670480915,
#  1705918.3652953075,
#  1690067.8206442457,
#  1647841.1929647168,
#  1638621.7778712357,
#  1637398.7195279144,
#  1608968.3084604023,
#  1572205.9642965328,
#  1545932.0076607252,
#  1523261.2537328952,
#  1542174.7350981033,
#  1525137.4595373985,
#  1496175.0531230576]

# %%
plt.figure(figsize=(12,8), dpi=200)
plt.plot(range(1,31), ssd, 'o--')
plt.xlabel('K value')
plt.ylabel('Sum of squared distances')
plt.xticks(np.arange(1, 31, 1.0));

# %%
plt.figure(figsize=(12,8), dpi=200)
pd.Series(ssd).diff().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,8), dpi=200)
pd.Series(ssd).diff().plot(kind='bar')
plt.ylim(-40000, 25000)
# Out:
# (-40000.0, 25000.0)

# %% [markdown]
# Points of interest:
# Going from K=9, to K=10
# Going from K=16, to K=17
# Going from K=22, to K=23

# %%
model = KMeans(n_clusters=9)
model.fit_predict(scaled_X)
# Out:
# array([3, 1, 3, ..., 5, 5, 8])

# %%
cluster9_labels = model.fit_predict(scaled_X)

# %%
X['Cluster'] = cluster9_labels

# %%
X.corr()['Cluster'][:-1].sort_values()
# Out:
# emp.var.rate        -0.740505
# euribor3m           -0.725313
# cons.price.idx      -0.676512
# nr.employed         -0.595962
# contact_telephone   -0.535217
#                        ...
# loan_unknown         0.191240
# housing_unknown      0.191240
# month_nov            0.245700
# month_apr            0.298333
# contact_cellular     0.535217
# Name: Cluster, Length: 65, dtype: float64

# %%
X.corr()['Cluster'][:-1].sort_values().index
# Out:
# Index(['emp.var.rate', 'euribor3m', 'cons.price.idx', 'nr.employed',
#        'contact_telephone', 'cons.conf.idx', 'month_jun', 'month_aug',
#        'default_unknown', 'subscribed_no', 'housing_no', 'campaign',
#        'marital_married', 'poutcome_success', 'loan_no', 'month_may',
#        'job_technician', 'poutcome_nonexistent', 'education_basic.4y', 'age',
#        'job_housemaid', 'job_blue-collar', 'job_unknown', 'day_of_week_tue',
#        'day_of_week_wed', 'education_unknown', 'education_professional.course',
#        'education_basic.6y', 'day_of_week_fri', 'job_services',
#        'education_basic.9y', 'loan_yes', 'default_yes', 'marital_divorced',
#        'marital_unknown', 'month_jul', 'education_illiterate',
#        'job_self-employed', 'job_entrepreneur', 'job_unemployed',
#        'education_high.school', 'duration', 'job_admin.', 'previous',
#        'day_of_week_mon', 'job_management', 'day_of_week_thu', 'housing_yes',
# ...

# %%
plt.figure(figsize=(12,8), dpi=200)
sns.barplot(y=X.corr()['Cluster'][:-1].sort_values(), x=X.corr()['Cluster'][:-1].sort_values().index)
plt.xticks(rotation=90);

# %% [markdown]
# 16 - emp.var.rate: employment variation rate - quarterly indicator (numeric)<br>
# 19 - euribor3m: euribor 3 month rate - daily indicator (numeric)

# %%
sns.scatterplot(data=df, x='emp.var.rate', y='euribor3m')
# Out:
# <AxesSubplot:xlabel='emp.var.rate', ylabel='euribor3m'>

# %%
def run_model(k, scaled_X):
    model = KMeans(n_clusters=k)
    cluster_labels = model.fit_predict(scaled_X)
    X['Cluster'] = cluster_labels
    X.corr()['Cluster'][:-1].sort_values()
    print(X.corr()['Cluster'][:-1].sort_values())

    plt.figure(figsize=(12,8), dpi=200)
    sns.barplot(y=X.corr()['Cluster'][:-1].sort_values(), x=X.corr()['Cluster'][:-1].sort_values().index)
    plt.xticks(rotation=90);

# %%
run_model(16, scaled_X)
# Out:
# euribor3m              -0.584421
# poutcome_nonexistent   -0.524644
# emp.var.rate           -0.510272
# contact_telephone      -0.494719
# nr.employed            -0.474354
#                           ...
# month_mar               0.209483
# month_apr               0.330437
# previous                0.440939
# poutcome_failure        0.489682
# contact_cellular        0.494719
# Name: Cluster, Length: 65, dtype: float64

# %%
sns.countplot(data=df, x='poutcome', hue='contact')
# Out:
# <AxesSubplot:xlabel='poutcome', ylabel='count'>

# %% [markdown]
# 15 - poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')<br>
# 8 - contact: contact communication type (categorical: 'cellular','telephone')<br>
# With K=16, previous outcome and type of contact seems to suggest there may be clusters present.

# %%
run_model(22, scaled_X)
# Out:
# month_nov            -0.310395
# month_jun            -0.309145
# job_student          -0.194023
# loan_yes             -0.163000
# education_basic.6y   -0.143132
#                         ...
# education_basic.4y    0.190625
# month_aug             0.209249
# loan_unknown          0.248156
# housing_unknown       0.248156
# month_apr             0.291051
# Name: Cluster, Length: 65, dtype: float64

# %% [markdown]
# month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# With K=22, There seem to be specific months where clusters emerge.
